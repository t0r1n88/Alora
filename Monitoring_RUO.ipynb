# %%
"""
скрипт для обработки данных по мониторингу РУО
"""
# Out:
# '\nскрипт для обработки данных по мониторингу РУО\n'

# %%
import pandas as pd

# %%
df = pd.read_excel('data/2023-07-25 Monitoring RUO.xlsx')

# %%
df.head()
# Out:
#            ID       Время создания  \
# 0  1444127966  2023-07-25 03:27:39
# 1  1443679056  2023-07-24 14:17:51
# 2  1443661130  2023-07-24 13:57:56
# 3  1443623045  2023-07-24 13:14:12
# 4  1443505375  2023-07-24 10:58:40
#
#                             Наименование организации  \
# 0  МКУ "Управление образование АМО "Тункинский ра...
# 1  Муниципальное автономное общеобразовательное у...
# 2  Муниципальное автономное общеобразовательное у...
# 3  Муниципальное казенное учреждение "Селенгинско...
# 4       МКУ "РУО" Администрации МО "Кабанский район"
#
#   ФИО ответственного за заполнение  \
# 0        Шаронова Ольга Викторовна
# 1       Колобкова Татьяна Ивановна
# 2       Колобкова Татьяна Ивановна
# 3          Очирова Ситора Ашуровна
# 4     Курбатова Евгения Михайловна
#
#   Номер телефона ответственного за заполнение  \
# 0                                 89085949544
# 1                                 83014323428
# 2                             8(30143)23-4-28
# ...
