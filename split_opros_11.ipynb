# %%
import pandas as pd
import re

# %%
def clean_end(value:str):
    
    value = value.strip()
    if value.endswith(','):
        return value[:-1]
    elif value.endswith('.'):
        return value[:-1]
    else:
        return value

# %%
def split_column(value):
    if isinstance(value,str):
        value = re.findall(r'([ЁА-Я][а-я,-;.\(\)\s]+)',value)
        temp_lst = list(map(clean_end,value))
        value = '&'.join(temp_lst)
        return value
    else:
        return None

# %%
df_11_main = pd.read_excel('data/Opros/11 класс Исходный.xlsx',dtype=str)

# %%
df_11_main.head()
# Out:
#   1. Укажите Ваш пол 2. Укажите Ваш возраст  \
# 0            Женский                     17
# 1            Женский                     17
# 2            Женский                     17
# 3            Женский                     18
# 4            Женский                     17
#
#   3. Укажите Ваше муниципальное образование/ район  \
# 0                               Баргузинский район
# 1                               Баргузинский район
# 2                               Баргузинский район
# 3                               Баргузинский район
# 4                               Баргузинский район
#
#   4. Укажите Ваш населенный пункт 5. Укажите наименование / номер школы  \
# 0                        Баргузин             МБОУ Баргузинская СОШ №27
# 1                        Баргузин                 МБОУ Баргузинская СОШ
# 2                        Баргузин                 МБОУ Баргузинская СОШ
# 3                        Баргузин             МБОУ Баргузинская СОШ №27
# ...

# %%
# Обработка 7 колонки
df_7 = df_7 = df_11_main['7. Укажите, какие предметы вы изучаете углубленно:'].str.split(',', expand=True).astype(str)

df_11_main.insert(7,'7.1 Укажите, какие предметы вы изучаете углубленно:',df_7[0])
df_11_main.insert(8,'7.2 Укажите, какие предметы вы изучаете углубленно:',df_7[1])
df_11_main.insert(9,'7.3 Укажите, какие предметы вы изучаете углубленно:',df_7[2])
df_11_main.insert(10,'7.4 Укажите, какие предметы вы изучаете углубленно:',df_7[3])
df_11_main.insert(11,'7.5 Укажите, какие предметы вы изучаете углубленно:',df_7[4])

# %%
[(idx,name_column) for idx,name_column in enumerate(df_11_main)]
# Out:
# [(0, '1. Укажите Ваш пол'),
#  (1, '2. Укажите Ваш возраст'),
#  (2, '3. Укажите Ваше муниципальное образование/ район'),
#  (3, '4. Укажите Ваш населенный пункт'),
#  (4, '5. Укажите наименование / номер школы'),
#  (5, '6. По какому профилю вы обучаетесь?'),
#  (6, '7. Укажите, какие предметы вы изучаете углубленно:'),
#  (7, '7.1 Укажите, какие предметы вы изучаете углубленно:'),
#  (8, '7.2 Укажите, какие предметы вы изучаете углубленно:'),
#  (9, '7.3 Укажите, какие предметы вы изучаете углубленно:'),
#  (10, '7.4 Укажите, какие предметы вы изучаете углубленно:'),
#  (11, '7.5 Укажите, какие предметы вы изучаете углубленно:'),
#  (12, 'Unnamed: 7'),
#  (13, 'Unnamed: 8'),
#  (14, 'Unnamed: 9'),
#  (15, 'Unnamed: 10'),
#  (16,
#   '8. Чем Вы в основном руководствуетесь при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):'),
#  (17,
#   '9. Какую роль (статус) Вы выбрали для себя в профессиональной деятельности?'),
#  (18,
# ...

# %%
# Колонка 8
df_11_main['8. Чем Вы в основном руководствуетесь при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):'] = df_11_main['8. Чем Вы в основном руководствуетесь при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):'].apply(split_column)




df_8 = df_11_main['8. Чем Вы в основном руководствуетесь при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):'].str.split('&', expand=True).astype(str)

df_11_main.insert(17,'8.1 Чем Вы в основном руководствуетесь при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):',df_8[0])
df_11_main.insert(18,'8.2 Чем Вы в основном руководствуетесь при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):',df_8[1])

# %%
[(idx,name_column) for idx,name_column in enumerate(df_11_main)]
# Out:
# [(0, '1. Укажите Ваш пол'),
#  (1, '2. Укажите Ваш возраст'),
#  (2, '3. Укажите Ваше муниципальное образование/ район'),
#  (3, '4. Укажите Ваш населенный пункт'),
#  (4, '5. Укажите наименование / номер школы'),
#  (5, '6. По какому профилю вы обучаетесь?'),
#  (6, '7. Укажите, какие предметы вы изучаете углубленно:'),
#  (7, '7.1 Укажите, какие предметы вы изучаете углубленно:'),
#  (8, '7.2 Укажите, какие предметы вы изучаете углубленно:'),
#  (9, '7.3 Укажите, какие предметы вы изучаете углубленно:'),
#  (10, '7.4 Укажите, какие предметы вы изучаете углубленно:'),
#  (11, '7.5 Укажите, какие предметы вы изучаете углубленно:'),
#  (12, 'Unnamed: 7'),
#  (13, 'Unnamed: 8'),
#  (14, 'Unnamed: 9'),
#  (15, 'Unnamed: 10'),
#  (16,
#   '8. Чем Вы в основном руководствуетесь при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):'),
#  (17,
# ...

# %%
# Колонка 11
df_11_main['11. Какой вид экономической деятельности (сферу деятельности) Вы предпочли бы при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):'] = df_11_main['11. Какой вид экономической деятельности (сферу деятельности) Вы предпочли бы при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):'].apply(split_column)
df_11 = df_11_main['11. Какой вид экономической деятельности (сферу деятельности) Вы предпочли бы при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):'].str.split('&', expand=True).astype(str)
df_11_main.insert(22,'11.1 Какой вид экономической деятельности (сферу деятельности) Вы предпочли бы при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):',df_11[0])
df_11_main.insert(23,'11.2 Какой вид экономической деятельности (сферу деятельности) Вы предпочли бы при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):',df_11[1])

# %%
[(idx,name_column) for idx,name_column in enumerate(df_11_main)]
# Out:
# [(0, '1. Укажите Ваш пол'),
#  (1, '2. Укажите Ваш возраст'),
#  (2, '3. Укажите Ваше муниципальное образование/ район'),
#  (3, '4. Укажите Ваш населенный пункт'),
#  (4, '5. Укажите наименование / номер школы'),
#  (5, '6. По какому профилю вы обучаетесь?'),
#  (6, '7. Укажите, какие предметы вы изучаете углубленно:'),
#  (7, '7.1 Укажите, какие предметы вы изучаете углубленно:'),
#  (8, '7.2 Укажите, какие предметы вы изучаете углубленно:'),
#  (9, '7.3 Укажите, какие предметы вы изучаете углубленно:'),
#  (10, '7.4 Укажите, какие предметы вы изучаете углубленно:'),
#  (11, '7.5 Укажите, какие предметы вы изучаете углубленно:'),
#  (12, 'Unnamed: 7'),
#  (13, 'Unnamed: 8'),
#  (14, 'Unnamed: 9'),
#  (15, 'Unnamed: 10'),
#  (16,
#   '8. Чем Вы в основном руководствуетесь при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):'),
#  (17,
# ...

# %%
# Колонка 13.1
df_11_main['13.1 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3'] = df_11_main['13.1 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3'].apply(split_column)
df_13_1 = df_11_main['13.1 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3'].str.split('&', expand=True).astype(str)
df_11_main.insert(23,'13.1.1 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3',df_13_1[0])
df_11_main.insert(24,'13.1.2 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3',df_13_1[1])
df_11_main.insert(25,'13.1.3 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3',df_13_1[2])

# %%
[(idx,name_column) for idx,name_column in enumerate(df_11_main)]

# %%
# Колонка 13.3
df_11_main['13.3 Если у Вас есть предположительный вариант, укажите, какой именно (не более 3 вариантов) '] = df_11_main['13.3 Если у Вас есть предположительный вариант, укажите, какой именно (не более 3 вариантов) '].apply(split_column)
df_13_3 = df_11_main['13.3 Если у Вас есть предположительный вариант, укажите, какой именно (не более 3 вариантов) '].str.split('&', expand=True).astype(str)
df_11_main.insert(28,'13.3.1 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3',df_13_3[0])
df_11_main.insert(29,'13.3.2 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3',df_13_3[1])
df_11_main.insert(30,'13.3.3 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3',df_13_3[2])

# %%
# Колонка 16
df_11_main['16. Что Вы делаете для того, чтобы подготовить себя к будущей специальности/направлению подготовки/профессии?'] = df_11_main['16. Что Вы делаете для того, чтобы подготовить себя к будущей специальности/направлению подготовки/профессии?'].apply(split_column)
df_16 = df_11_main['16. Что Вы делаете для того, чтобы подготовить себя к будущей специальности/направлению подготовки/профессии?'].str.split('&', expand=True).astype(str)
df_11_main.insert(36,'16.1 Что Вы делаете для того, чтобы подготовить себя к будущей специальности/направлению подготовки/профессии?',df_16[0])
df_11_main.insert(37,'16.2 Что Вы делаете для того, чтобы подготовить себя к будущей специальности/направлению подготовки/профессии?',df_16[1])
df_11_main.insert(38,'16.3 Что Вы делаете для того, чтобы подготовить себя к будущей специальности/направлению подготовки/профессии?',df_16[2])

# %%
[(idx,name_column) for idx,name_column in enumerate(df_11_main)]

# %%
# Колонка 18
df_11_main['18. Какие направления экономики Вы считаете приоритетными для развития в Республике Бурятия? (укажите не более 3 сфер)'] = df_11_main['18. Какие направления экономики Вы считаете приоритетными для развития в Республике Бурятия? (укажите не более 3 сфер)'].apply(split_column)
df_18 = df_11_main['18. Какие направления экономики Вы считаете приоритетными для развития в Республике Бурятия? (укажите не более 3 сфер)'].str.split('&', expand=True).astype(str)
df_11_main.insert(42,'18.1 Какие направления экономики Вы считаете приоритетными для развития в Республике Бурятия? (укажите не более 3 сфер)',df_18[0])
df_11_main.insert(43,'18.2 Какие направления экономики Вы считаете приоритетными для развития в Республике Бурятия? (укажите не более 3 сфер)',df_18[1])
df_11_main.insert(44,'18.3 Какие направления экономики Вы считаете приоритетными для развития в Республике Бурятия? (укажите не более 3 сфер)',df_18[2])

# %%
df_11_main.drop(columns=['6. Укажите, какие предметы вы изучаете углубленно:',
                        '7. Чем Вы в основном руководствуетесь при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):',
                        '9. Какой вид экономической деятельности Вы предпочли бы при выборе специальности/направления подготовки/профессии? (выберите не более ДВУХ ответов):',
                        '13.1 Укажите, к какой группе относятся выбранные Вами специальности/направления подготовки/профессии. Укажите не более 3',
                        '13.3 Если у Вас есть предположительный вариант, укажите, какой именно (не более 3 вариантов) ',
                        '16. Что Вы делаете для того, чтобы подготовить себя к будущей специальности/направлению подготовки/профессии?',
                       '18. Какие направления экономики Вы считаете приоритетными для развития в Республике Бурятия? (укажите не более 3 сфер)'],inplace=True)

# %%
df_11_main = df_11_main.applymap(lambda x: x.strip() if isinstance(x,str) else x)
df_11_main = df_11_main.applymap(lambda x: x[:-1] if isinstance(x,str) and x.endswith('.') else x)

# %%
df_11_main.replace('None',None,inplace=True)

# %%
df_11_main.to_excel('Для расчетов 11 класс.xlsx',index=False)

# %%
print('Lindy Booth')
